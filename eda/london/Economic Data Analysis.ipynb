# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# **Housing Sales**

# %%
hosts = ['Barking and Dagenham', 'Greenwich', 'Hackney', 'Newham', 'Tower Hamlets', 'Waltham Forest']

# %%
housing = pd.read_csv('housing-sales-borough.csv')
housing = housing.drop(columns=['Code'])
housing = housing.T
housing['Total'] = housing.sum(axis=1)
housing['Total']['Area'] = 'All Boroughs'
housing = housing.rename(columns=housing.iloc[0])
housing = housing.drop(['Area'])
housing['All Boroughs'] = housing['All Boroughs'].astype(int)
housing.head()
# Out:
#            City of London Barking and Dagenham Barnet Bexley Brent Bromley  \
# Sales-1995            155                  660   4047   2415  2632    3976
# Sales-1996            275                  883   5367   2934  3035    5408
# Sales-1997            319                 1451   6282   3734  3731    6306
# Sales-1998            428                 1921   6073   3618  4067    5645
# Sales-1999            536                 2261   7420   4561  4553    6900
#
#            Camden Croydon Ealing Enfield Greenwich Hackney  \
# Sales-1995   2542    3456   3377    3541      1776    1167
# Sales-1996   3403    4692   4411    4304      2122    1468
# Sales-1997   3891    5716   5323    5156      2567    2294
# Sales-1998   3551    6180   5229    5397      2933    2583
# Sales-1999   4026    7241   6170    6056      3976    2962
#
#            Hammersmith and Fulham Haringey Harrow Havering Hillingdon  \
# Sales-1995                   2727     2514   2450     2497       2840
# Sales-1996                   3706     3053   3152     3073       3890
# Sales-1997                   3988     3820   3591     3567       4325
# Sales-1998                   3433     3743   3664     3353       4454
# Sales-1999                   4214     4495   4389     4102       5720
#
#            Hounslow Islington Kensington and Chelsea Kingston upon Thames  \
# Sales-1995     2934      1572                   3310                 2655
# Sales-1996     3257      2208                   4234                 3174
# Sales-1997     4027      2954                   4660                 3891
# Sales-1998     3288      3094                   4084                 3478
# Sales-1999     4180      3723                   5071                 4055
#
#            Lambeth Lewisham Merton Newham Redbridge Richmond upon Thames  \
# Sales-1995    2521     1967   2649   1173      3081                 3300
# Sales-1996    3722     2592   3405   1605      3735                 4738
# Sales-1997    4919     3667   3951   2382      4215                 5152
# Sales-1998    5177     3930   4021   2930      4172                 4774
# Sales-1999    5777     5073   4958   3597      5142                 5906
#
#            Southwark Sutton Tower Hamlets Waltham Forest Wandsworth  \
# Sales-1995      1937   2587          1611           1922       4813
# Sales-1996      2305   3259          1986           2404       6378
# Sales-1997      3569   3774          3291           3198       7646
# Sales-1998      3945   4083          4194           3766       7237
# Sales-1999      4916   4829          5394           4749       9360
#
#            Westminster Inner London Outer London North East North West  \
# Sales-1995        3735        31744        52795      32440      93076
# Sales-1996        4580        41515        67243      37458     106047
# Sales-1997        6263        53663        79957      40890     118563
# Sales-1998        5357        53686        80116      41524     118080
# Sales-1999        6644        65788        97168      44150     130355
#
#            Yorkshire And The Humber East Midlands West Midlands    East  \
# Sales-1995                    70509         64029         71118   92578
# Sales-1996                    80027         76173         84421  113946
# Sales-1997                    88355         85699         93173  130498
# Sales-1998                    86566         84156         89800  124038
# Sales-1999                    97155         96184        102266  144099
#
#             London South East South West  England  Wales England & Wales  \
# Sales-1995   84539     141466      82253   732008  33321          765329
# Sales-1996  108758     176362     105672   888864  40781          929645
# Sales-1997  133620     201018     121982  1013798  46864         1060662
# Sales-1998  133802     187416     116864   982246  44182         1026428
# Sales-1999  162956     214965     135249  1127379  48503         1175882
#
#             All Boroughs
# Sales-1995       2431744
# Sales-1996       2965670
# Sales-1997       3402362
# Sales-1998       3302706
# Sales-1999       3805055

# %%
nonHosts = []
for bor in housing.columns:
    if bor not in hosts:
        nonHosts.append(bor)

# %%
plt.plot(housing['All Boroughs'])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.show()

# %%
# Plot Hosts
for host in hosts:
    housing[host] = housing[host].astype(int)
    plt.plot(housing[host])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.legend(hosts)
plt.show()

# %%
# Plot Non-hosts
for bor in nonHosts:
    if bor not in ['All Boroughs']:
        housing[bor] = housing[bor].astype(int)
        plt.plot(housing[bor])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.show()

# %%
c_zone = ['City of London','Camden','Islington','Kensington and Chelsea','Lambeth','Southwark','Westminster']
e_zone = ['Barking and Dagenham','Bexley','Greenwich','Hackney','Havering','Lewisham','Newham','Redbridge','Tower Hamlets','Waltham Forest']
n_zone = ['Barnet','Enfield','Haringey']
s_zone = ['Bromley','Croydon','Merton','Sutton','Wandsworth','Kingston upon Thames']
w_zone = ['Brent','Ealing','Hammersmith and Fulham','Harrow','Richmond upon Thames','Hillingdon','Hounslow']

# %%
housing = pd.read_csv('housing-sales-borough.csv')
housing = housing.drop(columns=['Code'])
housing.head()
# Out:
#                    Area  Sales-1995  Sales-1996  Sales-1997  Sales-1998  \
# 0        City of London         155         275         319         428
# 1  Barking and Dagenham         660         883        1451        1921
# 2                Barnet        4047        5367        6282        6073
# 3                Bexley        2415        2934        3734        3618
# 4                 Brent        2632        3035        3731        4067
#
#    Sales-1999  Sales-2000  Sales-2001  Sales-2002  Sales-2003  Sales-2004  \
# 0         536         431         365         391         474         375
# 1        2261        2595        3092        3423        3510        3516
# 2        7420        6560        6860        7350        6144        6557
# 3        4561        4188        5177        5703        5127        4934
# 4        4553        4426        4765        4849        4202        4021
#
#    Sales-2005  Sales-2006  Sales-2007  Sales-2008  Sales-2009  Sales-2010  \
# 0         304         295         268         141         157         236
# 1        2892        3666        3994        1696        1257        1447
# 2        5439        6789        6909        3469        3185        4158
# 3        4056        5002        5013        2499        2173        2459
# 4        3305        3963        4318        2084        1568        2391
#
#    Sales-2011  Sales-2012  Sales-2013  Sales-2014
# 0         256         195         429         267
# 1        1458        1316        1746        2028
# 2        3892        3973        4738        4794
# 3        2540        2815        3349        3827
# 4        2188        2021        2442        2795

# %%
housing['Zone'] = '' housing['Area'] in

# %%
for bor in c_zone:
    if bor not in ['All Boroughs']:
        housing[bor] = housing[bor].astype(int)
        plt.plot(housing[bor])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.title('Center Zone')
plt.show()

# %%
for bor in n_zone:
    if bor not in ['All Boroughs']:
        housing[bor] = housing[bor].astype(int)
        plt.plot(housing[bor])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.title('North Zone')
plt.show()

# %%
for bor in e_zone:
    if bor not in ['All Boroughs']:
        housing[bor] = housing[bor].astype(int)
        plt.plot(housing[bor])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.title('East Zone')
plt.show()

# %%
for bor in s_zone:
    if bor not in ['All Boroughs']:
        housing[bor] = housing[bor].astype(int)
        plt.plot(housing[bor])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.title('South Zone')
plt.show()

# %%
for bor in w_zone:
    if bor not in ['All Boroughs']:
        housing[bor] = housing[bor].astype(int)
        plt.plot(housing[bor])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.xticks(rotation=90)
plt.title('West Zone')
plt.show()

# %%
# Aggregated Sales by Zone
housing_zone = pd.read_csv('housing-sales-borough.csv')
housing_zone = housing_zone.drop(columns=['Code'])
housing_zone['Zone'] = ['West' if x in w_zone else ('North' if x in n_zone else ('East' if x in e_zone else ('South' if x in s_zone else 'Center'))) for x in housing_zone['Area']] 
housing_zone = housing_zone.drop(columns=['Area'])
housing_zone = housing_zone.groupby(['Zone']).agg(sum)
for year in range(1995,2009):
    housing_zone = housing_zone.drop(columns=['Sales-'+str(year)])
housing_zone = housing_zone.T
plt.plot(housing_zone['North'])
plt.plot(housing_zone['East'])
plt.plot(housing_zone['South'])
plt.plot(housing_zone['West'])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.legend(['North', 'East', 'South', 'West'])
plt.xticks(rotation=90)
plt.show()

# %%
housing_zone['Olympic Searches'] = [10,14,25,245,11,9]
housing_zone['Olympic Searches Bin'] = [0,0,0,1,0,0]
housing_zone
# Out:
# Zone         Center   East  North  South   West  Olympic Searches  \
# Sales-2009  1914589  20656   7569  18160  14753                10
# Sales-2010  2049604  24477   9360  20506  18978                14
# Sales-2011  2041066  23971   8858  20330  18704                25
# Sales-2012  2041236  25379   9123  21079  18717               245
# Sales-2013  2464488  31528  10760  25480  21568                11
# Sales-2014  2790758  36065  11239  26801  21572                 9
#
# Zone        Olympic Searches Bin
# Sales-2009                     0
# Sales-2010                     0
# Sales-2011                     0
# Sales-2012                     1
# Sales-2013                     0
# Sales-2014                     0

# %%
corrmat = housing_zone.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
housing_percent = pd.read_csv('housing-sales-borough.csv')
housing_percent = housing_percent.drop(columns=['Code'])
housing_percent['Zone'] = ['West' if x in w_zone else ('North' if x in n_zone else ('East' if x in e_zone else ('South' if x in s_zone else 'Center'))) for x in housing_percent['Area']] 
housing_percent = housing_percent.drop(columns=['Area'])
housing_percent = housing_percent.groupby(['Zone']).agg(sum)
for year in range(1996,2015):
    housing_percent[str(year)+'-Percent'] = housing_percent.apply(lambda row: (row['Sales-'+str(year)] - row['Sales-'+str(year-1)]) / row['Sales-'+str(year-1)], axis=1)
for year in range(1995,2015):
    housing_percent = housing_percent.drop(columns=['Sales-'+str(year)])
for year in range(1996,2009):
    housing_percent = housing_percent.drop(columns=[str(year)+'-Percent'])
housing_percent = housing_percent.T
plt.plot(housing_percent['North'])
plt.plot(housing_percent['East'])
plt.plot(housing_percent['South'])
plt.plot(housing_percent['West'])
plt.plot(housing_percent['Center'])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.legend(['North', 'East', 'South', 'West', 'Center'])
plt.xticks(rotation=90)
plt.show()

# %%
housing_percent = pd.read_csv('housing-sales-borough.csv')
housing_percent = housing_percent.drop(columns=['Code'])
housing_percent['Zone'] = ['West' if x in w_zone else ('North' if x in n_zone else ('East' if x in e_zone else ('South' if x in s_zone else 'Center'))) for x in housing_percent['Area']] 
housing_percent = housing_percent.drop(columns=['Area'])
housing_percent = housing_percent.groupby(['Zone']).agg(sum)
for year in range(1996,2015):
    housing_percent[str(year)+'-Percent'] = housing_percent.apply(lambda row: (row['Sales-'+str(year)] - row['Sales-'+str(year-1)]) / row['Sales-'+str(year-1)], axis=1)
for year in range(1995,2015):
    housing_percent = housing_percent.drop(columns=['Sales-'+str(year)])
for year in range(1996,2009):
    housing_percent = housing_percent.drop(columns=[str(year)+'-Percent'])
housing_percent = housing_percent.T
housing_percent
# Out:
# Zone            Center      East     North     South      West
# 2009-Percent -0.038832 -0.147714 -0.117318  0.012094 -0.103107
# 2010-Percent  0.070519  0.184983  0.236623  0.129185  0.286382
# 2011-Percent -0.004166 -0.020672 -0.053632 -0.008583 -0.014438
# 2012-Percent  0.000083  0.058738  0.029916  0.036842  0.000695
# 2013-Percent  0.207351  0.242287  0.179437  0.208786  0.152321
# 2014-Percent  0.132389  0.143904  0.044517  0.051845  0.000185

# %%
sns.set_style('darkgrid') 
plt.plot(range(2009,2015), housing_percent['Center'],'--o')
plt.plot(range(2009,2015), housing_percent['North'],'--o')
plt.plot(range(2009,2015), housing_percent['South'],'--o')
plt.plot(range(2009,2015), housing_percent['East'],'--o')
plt.plot(range(2009,2015), housing_percent['West'],'--o')
plt.legend(['Central','North','South','East','West'],loc=4) # loc just specifies the location of legend (1,2,3,4 are similar to quadrant position)
ax = plt.gca()
ax.axvspan(2012, 2014, alpha=0.5, color='grey')
ax.set_xlabel('Year')
ax.set_ylabel('% Change in Housing Sales')
ax.set_title('% Change in Housing Sales by Zones')
plt.savefig('Housing Sales.png', dpi=300)

# %%
housing_percent = pd.read_csv('housing-sales-borough.csv')
housing_percent = housing_percent.drop(columns=['Code'])
housing_percent['Zone'] = ['West' if x in w_zone else ('North' if x in n_zone else ('East' if x in e_zone else ('South' if x in s_zone else 'Center'))) for x in housing_percent['Area']] 
housing_percent = housing_percent.drop(columns=['Area'])
housing_percent = housing_percent.groupby(['Zone']).agg(sum)
for year in range(1996,2015):
    housing_percent[str(year)+'-Percent'] = housing_percent.apply(lambda row: (row['Sales-'+str(year)] - row['Sales-'+str(year-1)]) / row['Sales-'+str(year-1)], axis=1)
for year in range(1995,2015):
    housing_percent = housing_percent.drop(columns=['Sales-'+str(year)])
for year in range(1996,2005):
    housing_percent = housing_percent.drop(columns=[str(year)+'-Percent'])
housing_percent = housing_percent.T
housing_percent
sns.set_style('darkgrid') 
plt.plot(range(2005,2015), housing_percent['Center'],'--o')
plt.plot(range(2005,2015), housing_percent['North'],'--o')
plt.plot(range(2005,2015), housing_percent['South'],'--o')
plt.plot(range(2005,2015), housing_percent['East'],'--o')
plt.plot(range(2005,2015), housing_percent['West'],'--o')
plt.legend(['Central','North','South','East','West'],loc=4) # loc just specifies the location of legend (1,2,3,4 are similar to quadrant position)
ax = plt.gca()
ax.axvspan(2012, 2014, alpha=0.5, color='grey')
ax.set_xlabel('Year')
ax.set_ylabel('% Change in Housing Sales')
ax.set_title('% Change in Housing Sales by Zones')
plt.savefig('Housing Sales.png', dpi=300)

# %%
housing_percent['Year'] = [y for y in range(2005, 2015)]
housing_percent
# Out:
# Zone            Center      East     North     South      West  Year
# 2005-Percent -0.144529 -0.149199 -0.170269 -0.138375 -0.156166  2005
# 2006-Percent  0.250523  0.199326  0.268451  0.287439  0.274389  2006
# 2007-Percent -0.041029  0.005968 -0.006415 -0.048695 -0.036943  2007
# 2008-Percent -0.491658 -0.509303 -0.514357 -0.525832 -0.505115  2008
# 2009-Percent -0.038832 -0.147714 -0.117318  0.012094 -0.103107  2009
# 2010-Percent  0.070519  0.184983  0.236623  0.129185  0.286382  2010
# 2011-Percent -0.004166 -0.020672 -0.053632 -0.008583 -0.014438  2011
# 2012-Percent  0.000083  0.058738  0.029916  0.036842  0.000695  2012
# 2013-Percent  0.207351  0.242287  0.179437  0.208786  0.152321  2013
# 2014-Percent  0.132389  0.143904  0.044517  0.051845  0.000185  2014

# %%
housing_zone = pd.read_csv('housing-sales-borough.csv')
housing_zone = housing_zone.drop(columns=['Code'])
housing_zone['Zone'] = ['West' if x in w_zone else ('North' if x in n_zone else ('East' if x in e_zone else ('South' if x in s_zone else 'Center'))) for x in housing_zone['Area']] 
housing_zone = housing_zone.drop(columns=['Area'])
housing_zone = housing_zone.groupby(['Zone']).agg(sum)
for year in range(1995,2009):
    housing_zone = housing_zone.drop(columns=['Sales-'+str(year)])
housing_zone = housing_zone.T
plt.plot(housing_zone['North'])
plt.plot(housing_zone['East'])
plt.plot(housing_zone['South'])
plt.plot(housing_zone['West'])
plt.xlabel('Year'); plt.ylabel('Housing Sales');
plt.legend(['North', 'East', 'South', 'West'])
plt.xticks(rotation=90)
plt.show()
housing_zone
# Out:
# Zone         Center   East  North  South   West
# Sales-2009  1914589  20656   7569  18160  14753
# Sales-2010  2049604  24477   9360  20506  18978
# Sales-2011  2041066  23971   8858  20330  18704
# Sales-2012  2041236  25379   9123  21079  18717
# Sales-2013  2464488  31528  10760  25480  21568
# Sales-2014  2790758  36065  11239  26801  21572

# %%
housing_zone = pd.read_csv('housing-sales-borough.csv')
housing_zone = housing_zone.drop(columns=['Code'])
housing_zone['Zone'] = ['West' if x in w_zone else ('North' if x in n_zone else ('East' if x in e_zone else ('South' if x in s_zone else 'Center'))) for x in housing_zone['Area']] 
housing_zone = housing_zone.drop(columns=['Area'])
housing_zone = housing_zone.groupby(['Zone']).agg(sum)
housing_zone_test = housing_zone
housing_zone = housing_zone.T
housing_zone['Year'] = [y for y in range(1995, 2015)]
housing_zone_test = housing_zone

data = housing_zone_test
x_column = 'Year'
y_column = 'Center'
n_1, n_2 = 17, 3

def chow_test(x_column, y_column)
    def find_rss (data, x_column, y_column):
        x = data[[x_column]]
        y = data[y_column]
        lm = LinearRegression()
        lm.fit(x, y)
        rss = np.sum(np.square(y - lm.predict(x)))
        return rss
    rss_total = find_rss(data, x_column, y_column)
    rss_1 = find_rss(data.iloc[:17], x_column, y_column)
    rss_2 = find_rss(data.iloc[17:], x_column, y_column)
    chow_nom = (rss_total - (rss_1 + rss_2)) / 2
    chow_denom = (rss_1+rss_2) / (n_1 + n_2 - (2 * 2))
    chow = chow_nom / chow_denom

print(chow)
# Out:
# 0.39169436361489124

# %%
housing_zone_test
# Out:
# Zone         Center   East  North  South   West  Year
# Sales-2009  1914589  20656   7569  18160  14753  2009
# Sales-2010  2049604  24477   9360  20506  18978  2010
# Sales-2011  2041066  23971   8858  20330  18704  2011
# Sales-2012  2041236  25379   9123  21079  18717  2012
# Sales-2013  2464488  31528  10760  25480  21568  2013
# Sales-2014  2790758  36065  11239  26801  21572  2014

# %%
sns.set_style('darkgrid') 
plt.plot(range(1995,2015), housing_zone_test['Center'],'--o')
plt.plot(range(1995,2015), housing_zone_test['North'],'--o')
plt.plot(range(1995,2015), housing_zone_test['South'],'--o')
plt.plot(range(1995,2015), housing_zone_test['East'],'--o')
plt.plot(range(1995,2015), housing_zone_test['West'],'--o')
plt.legend(['Central','North','South','East','West'],loc=4) # loc just specifies the location of legend (1,2,3,4 are similar to quadrant position)
ax = plt.gca()
ax.axvspan(2012, 2014, alpha=0.5, color='grey')
ax.set_xlabel('Year')
ax.set_ylabel('% Change in Housing Sales')
ax.set_title('% Change in Housing Sales by Zones')
plt.savefig('Housing Sales.png', dpi=300)

# %%
from sklearn.linear_model import LinearRegression

data = housing_percent
x_column = 'West'
y_column = 'East'
n_1, n_2 = 3, 2

def find_rss (data, x_column, y_column):
    x = data[[x_column]]
    y = data[y_column]
    lm = LinearRegression()
    lm.fit(x, y)
    rss = np.sum(np.square(y - lm.predict(x)))
    return rss
rss_total = find_rss(data, x_column, y_column)
rss_1 = find_rss(data.iloc[:3], x_column, y_column)
rss_2 = find_rss(data.iloc[3:], x_column, y_column)
chow_nom = (rss_total - (rss_1 + rss_2)) / 2
chow_denom = (rss_1+rss_2) / (n_1 + n_2 - (2 * 2))
chow = chow_nom / chow_denom

print(chow)
# Out:
# 0.055256130807900296

# %%
housing_percent['Olympic Searches'] = [10,14,25,245,11,9]
housing_percent
# Out:
# Zone            Center      East     North     South      West  \
# 2009-Percent -0.038832 -0.147714 -0.117318  0.012094 -0.103107
# 2010-Percent  0.070519  0.184983  0.236623  0.129185  0.286382
# 2011-Percent -0.004166 -0.020672 -0.053632 -0.008583 -0.014438
# 2012-Percent  0.000083  0.058738  0.029916  0.036842  0.000695
# 2013-Percent  0.207351  0.242287  0.179437  0.208786  0.152321
# 2014-Percent  0.132389  0.143904  0.044517  0.051845  0.000185
#
# Zone          Olympic Searches
# 2009-Percent                10
# 2010-Percent                14
# 2011-Percent                25
# 2012-Percent               245
# 2013-Percent                11
# 2014-Percent                 9

# %%
corrmat = housing_percent.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# **Economic Inactivity**

# %%
inactivity = pd.read_csv('economic-inactivity.csv')
percent = [c for c in inactivity.columns if (c.startswith('percent') or c == 'Area')]
inactivity = inactivity[percent]
inactivity = inactivity.T
inactivity = inactivity.rename(columns=inactivity.iloc[0])
inactivity = inactivity.drop(['Area'])
inactivity = inactivity.drop(columns=['City of London'])
inactivity.head()
# Out:
#                            Barking and Dagenham Barnet Bexley Brent Bromley  \
# percent; Jan 2004-Dec 2004                 31.8   24.7     21  30.1    19.4
# percent; Jan 2005-Dec 2005                   31   25.6   20.5  28.4    17.2
# percent; Jan 2006-Dec 2006                   31     27     21    29      21
# percent; Jan 2007-Dec 2007                   28     27     23    25      17
# percent; Jan 2008-Dec 2008                   29     27     22    24      19
#
#                            Camden Croydon Ealing Enfield Greenwich Hackney  \
# percent; Jan 2004-Dec 2004     27    22.1   25.8    27.1      26.6    36.8
# percent; Jan 2005-Dec 2005   30.4    20.7   27.1    25.9      25.6    40.6
# percent; Jan 2006-Dec 2006     28      23     25      26        27      33
# percent; Jan 2007-Dec 2007     28      22     27      31        25      29
# percent; Jan 2008-Dec 2008     28      22     27      27        29      28
#
#                            Hammersmith and Fulham Haringey Harrow Havering  \
# percent; Jan 2004-Dec 2004                   25.3     35.2   23.5     22.1
# percent; Jan 2005-Dec 2005                   24.4     28.5   24.5     22.4
# percent; Jan 2006-Dec 2006                     24       27     22       23
# percent; Jan 2007-Dec 2007                     24       29     23       21
# percent; Jan 2008-Dec 2008                     24       33     27       19
#
#                            Hillingdon Hounslow Islington  \
# percent; Jan 2004-Dec 2004       21.9       24      30.7
# percent; Jan 2005-Dec 2005       24.3     22.4      32.8
# percent; Jan 2006-Dec 2006         23       21        28
# percent; Jan 2007-Dec 2007         31       27        26
# percent; Jan 2008-Dec 2008         23       25        27
#
#                            Kensington and Chelsea Kingston upon Thames  \
# percent; Jan 2004-Dec 2004                   32.3                   23
# percent; Jan 2005-Dec 2005                   29.4                 22.9
# percent; Jan 2006-Dec 2006                     34                   22
# percent; Jan 2007-Dec 2007                     30                   25
# percent; Jan 2008-Dec 2008                     30                   23
#
#                            Lambeth Lewisham Merton Newham Redbridge  \
# percent; Jan 2004-Dec 2004    24.3     23.3   18.6   39.3      22.5
# percent; Jan 2005-Dec 2005    27.2     23.4   23.9   38.4      30.9
# percent; Jan 2006-Dec 2006      30       24     21     35        27
# percent; Jan 2007-Dec 2007      24       25     19     36        30
# percent; Jan 2008-Dec 2008      24       23     17     34        29
#
#                            Richmond upon Thames Southwark Sutton  \
# percent; Jan 2004-Dec 2004                 25.1      26.2   21.6
# percent; Jan 2005-Dec 2005                 21.4      31.1   17.6
# percent; Jan 2006-Dec 2006                   21        29     18
# percent; Jan 2007-Dec 2007                   19        29     20
# percent; Jan 2008-Dec 2008                   21        27     21
#
#                            Tower Hamlets Waltham Forest Wandsworth  \
# percent; Jan 2004-Dec 2004          38.4           31.7       20.4
# percent; Jan 2005-Dec 2005          34.6           27.6       22.5
# percent; Jan 2006-Dec 2006            38             28         23
# percent; Jan 2007-Dec 2007            37             28         21
# percent; Jan 2008-Dec 2008            30             30         19
#
#                            Westminster Inner London Outer London North East  \
# percent; Jan 2004-Dec 2004        31.2         29.6         24.3       27.6
# percent; Jan 2005-Dec 2005        30.6           30         24.3       26.9
# percent; Jan 2006-Dec 2006          32           29           24         26
# percent; Jan 2007-Dec 2007          33           28           25         26
# percent; Jan 2008-Dec 2008          32           27           24         26
#
#                            North West Yorkshire and The Humber East Midlands  \
# percent; Jan 2004-Dec 2004       25.9                     24.4          23.2
# percent; Jan 2005-Dec 2005       25.5                     24.1          22.5
# percent; Jan 2006-Dec 2006         25                       24            22
# percent; Jan 2007-Dec 2007         25                       25            22
# percent; Jan 2008-Dec 2008         26                       24            22
#
#                            West Midlands  East London South East South West  \
# percent; Jan 2004-Dec 2004          24.5  20.2   26.5       19.8       21.5
# percent; Jan 2005-Dec 2005          24.5  20.5   26.6       19.6       21.6
# percent; Jan 2006-Dec 2006            25    21     26         20         21
# percent; Jan 2007-Dec 2007            25    21     26         20         21
# percent; Jan 2008-Dec 2008            25    21     26         20         21
#
#                            Wales Scotland Northern Ireland England  \
# percent; Jan 2004-Dec 2004  27.3     23.3             30.3    23.5
# percent; Jan 2005-Dec 2005    27     22.9             29.8    23.4
# percent; Jan 2006-Dec 2006    27       22               30      23
# percent; Jan 2007-Dec 2007    27       22               29      23
# percent; Jan 2008-Dec 2008    27       23               29      23
#
#                            England and Wales Great Britain United Kingdom
# percent; Jan 2004-Dec 2004              23.7          23.7           23.9
# percent; Jan 2005-Dec 2005              23.6          23.5           23.7
# percent; Jan 2006-Dec 2006                23            23             23
# percent; Jan 2007-Dec 2007                24            23             24
# percent; Jan 2008-Dec 2008                23            23             24

# %%
inactivity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Area                        51 non-null     object
#  1   percent; Jan 2004-Dec 2004  51 non-null     object
#  2   percent; Jan 2005-Dec 2005  51 non-null     float64
#  3   percent; Jan 2006-Dec 2006  51 non-null     int64
#  4   percent; Jan 2007-Dec 2007  51 non-null     object
#  5   percent; Jan 2008-Dec 2008  51 non-null     object
#  6   percent; Jan 2009-Dec 2009  51 non-null     object
#  7   percent; Jan 2010-Dec 2010  51 non-null     object
#  8   percent; Jan 2011-Dec 2011  51 non-null     object
#  9   percent; Jan 2012-Dec 2012  51 non-null     object
#  10  percent; Jan 2013-Dec 2013  51 non-null     object
#  11  percent; Jan 2014-Dec 2014  51 non-null     float64
#  12  percent; Jan 2015-Dec 2015  51 non-null     int64
#  13  percent; Jan 2016-Dec 2016  51 non-null     object
#  14  percent; Jan 2017-Dec 2017  51 non-null     int64
#  15  percent; Jan 2018-Dec 2018  51 non-null     object
#  16  percent; Jan 2019-Dec 2019  51 non-null     object
# dtypes: float64(2), int64(3), object(12)
# memory usage: 6.9+ KB

# %%
# Plot Hosts
for host in hosts:
    inactivity[host] = inactivity[host].astype(float)
    plt.plot(inactivity[host])
plt.xlabel('Year'); plt.ylabel('Percentage Inactive');
plt.xticks(rotation=90)
plt.legend(hosts)
plt.show()
