# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
low_quartile = pd.read_csv('low_quartile_plotting.csv')
low_quartile.head()

plt.figure()

plt.plot(range(2008,2014),low_quartile.iloc[8,2:],'--o')
plt.plot(range(2008,2014),low_quartile.iloc[9,2:],'--o')
plt.plot(range(2008,2014),low_quartile.iloc[10,2:],'--o')
plt.plot(range(2008,2014),low_quartile.iloc[11,2:],'--o')
plt.plot(range(2008,2014),low_quartile.iloc[12,2:],'--o')
plt.legend(['Central','North','South','East','West'],loc=3)
# # # #x = plt.gca().xaxis 
ax = plt.gca()
ax.axvspan(2011, 2013, alpha=0.5, color='grey')
ax.set_xlabel('Year')
ax.set_ylabel('% Change')
ax.set_title('% Change in Average Low Quartile Income by Zones')
plt.savefig('low_quartile_income.png', dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Median_yearly = pd.read_csv('FT_median.csv')
Median_yearly.head()
c_zone = ['City of London','Camden','Islington','Kensington and Chelsea','Lambeth','Southwark','Westminster']
central = Median_yearly[Median_yearly.Area.isin(c_zone)]
e_zone = ['Barking and Dagenham','Bexley','Greenwich','Hackney','Havering','Lewisham','Newham','Redbridge','Tower Hamlets','Waltham Forest']
east = Median_yearly[Median_yearly.Area.isin(e_zone)]
n_zone = ['Barnet','Enfield','Haringey']
north = Median_yearly[Median_yearly.Area.isin(n_zone)]
s_zone = ['Bromley','Croydon','Merton','Sutton','Wandsworth','Kingston upon Thames']
south = Median_yearly[Median_yearly.Area.isin(s_zone)]
w_zone = ['Brent','Ealing','Hammersmith and Fulham','Harrow','Richmond upon Thames','Hallingdon','Hounslow']
west = Median_yearly[Median_yearly.Area.isin(w_zone)]

# %%
central = central.iloc[:,1:]
north = north.iloc[:,1:]
south = south.iloc[:,1:]
east = east.iloc[:,1:]
west = west.iloc[:,1:]

# %%
west.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/west_median.csv', index = False)
east.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/east_median.csv', index = False)
north.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/north_median.csv', index = False)
south.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/south_median.csv', index = False)
central.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/central_median.csv', index = False)

# %%
central.iloc[:,1:2]
# Out:
#       1999
# 1   33,020
# 7   23,677
# 19  25,113
# 20  20,646
# 22  23,151
# 28  22,784
# 33  24,447

# %%
Median_plotting = pd.read_csv('Median_Plotting.csv')
Median_plotting
# Out:
#    Unnamed: 0      1999      2000      2001      2002      2003      2004  \
# 0       north  19213.33  21333.33  21800.33  23246.00  22904.33  25447.50
# 1      south   19241.67  20414.67  20673.33  21890.83  22901.00  23855.00
# 2        east  20569.60  21587.40  22196.30  22823.90  24007.10  25696.50
# 3        west  21197.33  23027.67  23611.83  24131.67  25260.33  26475.33
# 4     central  24691.14  26429.86  28250.57  29888.71  30883.43  31341.43
# 5         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       north       NaN     11.03      2.19      6.63     -1.47     11.10
# 8      south        NaN      6.10      1.27      5.89      4.61      4.17
# 9        east       NaN      4.95      2.82      2.83      5.18      7.04
# 10       west       NaN      8.63      2.54      2.20      4.68      4.81
# 11    central       NaN      7.04      6.89      5.80      3.33      1.48
# ...

# %%
plt.figure()
plt.plot(range(1999,2014),Median_plotting.iloc[0,1:16],'--o')
plt.plot(range(1999,2014),Median_plotting.iloc[1,1:16],'--o')
plt.plot(range(1999,2014),Median_plotting.iloc[2,1:16],'--o')
plt.plot(range(1999,2014),Median_plotting.iloc[3,1:16],'--o')
plt.plot(range(1999,2014),Median_plotting.iloc[4,1:16],'--o')
plt.legend(['North','South','East','West','Central'],loc=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
import seaborn as sns
sns.set_style('darkgrid')
plt.plot(range(2008,2014),Median_plotting.iloc[18,10:16],'--o')
plt.plot(range(2008,2014),Median_plotting.iloc[14,10:16],'--o')
plt.plot(range(2008,2014),Median_plotting.iloc[15,10:16],'--o')
plt.plot(range(2008,2014),Median_plotting.iloc[16,10:16],'--o')
plt.plot(range(2008,2014),Median_plotting.iloc[17,10:16],'--o')
# plt.plot(range(2008,2014),Median_plotting.iloc[18,10:16],'--o')
plt.legend(['Central','North','South','East','West'],loc=3)
ax = plt.gca()
ax.axvspan(2011, 2013, alpha=0.5, color='grey')
ax.set_xlabel('Year')
ax.set_ylabel('% Change')
ax.set_title('% Change in Average Annual Median Income by Zones')
plt.savefig('Median_Income.png', dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Central going down for short term purposes (2011-2013) while South and East gaining during 2012-2013 (With East also gaining in 2011-2012)

# %%
job_density = pd.read_csv('job_density.csv')
job_density.head()
c_zone = ['City of London','Camden','Islington','Kensington and Chelsea','Lambeth','Southwark','Westminster']
central = job_density[job_density.area.isin(c_zone)]
e_zone = ['Barking and Dagenham','Bexley','Greenwich','Hackney','Havering','Lewisham','Newham','Redbridge','Tower Hamlets','Waltham Forest']
east = job_density[job_density.area.isin(e_zone)]
n_zone = ['Barnet','Enfield','Haringey']
north = job_density[job_density.area.isin(n_zone)]
s_zone = ['Bromley','Croydon','Merton','Sutton','Wandsworth','Kingston upon Thames']
south = job_density[job_density.area.isin(s_zone)]
w_zone = ['Brent','Ealing','Hammersmith and Fulham','Harrow','Richmond upon Thames','Hillingdon','Hounslow']
west = job_density[job_density.area.isin(w_zone)]

# %%
central = central.iloc[:,2:]
north = north.iloc[:,2:]
south = south.iloc[:,2:]
east = east.iloc[:,2:]
west = west.iloc[:,2:]

# %%
# Out:
#                        area  year  number_of_jobs  job_density
# 0            City of London  2000          361000        67.10
# 6                    Camden  2000          291000         2.05
# 18                Islington  2000          173000         1.36
# 19   Kensington and Chelsea  2000          147000         1.31
# 21                  Lambeth  2000          140000         0.73
# ..                      ...   ...             ...          ...
# 851               Islington  2017          247000         1.40
# 852  Kensington and Chelsea  2017          165000         1.56
# 854                 Lambeth  2017          187000         0.78
# 860               Southwark  2017          316000         1.37
# 865             Westminster  2017          759000         4.36
#
# [126 rows x 4 columns]

# %%
west.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/west_density.csv', index = False)
east.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/east_density.csv', index = False)
north.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/north_density.csv', index = False)
south.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/south_density.csv', index = False)
central.to_csv(r'/Users/rajpatel/Documents/Summer Invitational/datasets_full/central_density.csv', index = False)

# %%
pd.options.display.max_rows = 200
central.groupby(['year'])['number_of_jobs'].sum()
# Out:
# year
# 2000    1910000
# 2001    1882000
# 2002    1841000
# 2003    1856000
# 2004    1854000
# 2005    1917000
# 2006    1882000
# 2007    1958000
# 2008    2015000
# 2009    2031000
# 2010    2044000
# 2011    2176000
# 2012    2263000
# 2013    2320000
# 2014    2448000
# 2015    2554000
# 2016    2602000
# 2017    2700000
# Name: number_of_jobs, dtype: int64

# %%
north.groupby(['year'])['number_of_jobs'].sum()
# Out:
# year
# 2000    325000
# 2001    324000
# 2002    314000
# 2003    327000
# 2004    323000
# 2005    336000
# 2006    326000
# 2007    325000
# 2008    329000
# 2009    325000
# 2010    325000
# 2011    331000
# 2012    351000
# 2013    361000
# 2014    382000
# 2015    394000
# 2016    389000
# 2017    395000
# Name: number_of_jobs, dtype: int64

# %%
south.groupby(['year'])['number_of_jobs'].sum()
# Out:
# year
# 2000    649000
# 2001    634000
# 2002    624000
# 2003    633000
# 2004    654000
# 2005    638000
# 2006    651000
# 2007    653000
# 2008    653000
# 2009    613000
# 2010    612000
# 2011    624000
# 2012    648000
# 2013    646000
# 2014    660000
# 2015    685000
# 2016    688000
# 2017    729000
# Name: number_of_jobs, dtype: int64

# %%
east.groupby(['year'])['number_of_jobs'].sum()
# Out:
# year
# 2000     872000
# 2001     868000
# 2002     869000
# 2003     873000
# 2004     909000
# 2005     920000
# 2006     879000
# 2007     897000
# 2008     915000
# 2009     901000
# 2010     913000
# 2011     971000
# 2012    1004000
# 2013    1042000
# 2014    1106000
# 2015    1146000
# 2016    1169000
# 2017    1211000
# Name: number_of_jobs, dtype: int64

# %%
west.groupby(['year'])['number_of_jobs'].sum()
# Out:
# year
# 2000     862000
# 2001     873000
# 2002     846000
# 2003     865000
# 2004     872000
# 2005     896000
# 2006     879000
# 2007     895000
# 2008     885000
# 2009     866000
# 2010     879000
# 2011     926000
# 2012     962000
# 2013     971000
# 2014    1006000
# 2015    1032000
# 2016    1058000
# 2017    1087000
# Name: number_of_jobs, dtype: int64

# %%
jobs_plotting = pd.read_csv('Jobs_available.csv')
jobs_plotting.iloc[7,2:11]
#jobs_plotting
plt.figure()
import seaborn as sns
sns.set_style('darkgrid')
plt.plot(range(2008,2015),jobs_plotting.iloc[7,2:9],'--o')
plt.plot(range(2008,2015),jobs_plotting.iloc[8,2:9],'--o')
plt.plot(range(2008,2015),jobs_plotting.iloc[9,2:9],'--o')
plt.plot(range(2008,2015),jobs_plotting.iloc[10,2:9],'--o')
plt.plot(range(2008,2015),jobs_plotting.iloc[11,2:9],'--o')
plt.legend(['Central','North','South','East','West'],loc=4)
ax = plt.gca()
ax.axvspan(2012, 2014, alpha=0.5, color='grey')
ax.set_xlabel('Year')
ax.set_ylabel('% Change')
ax.set_title('% Change in Number of Jobs Available by Zones')
plt.savefig('Jobs.png', dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.linear_model import LinearRegression
data = jobs_plotting # housing data column (zones), row (years)
#data.head()
x_column = 'Year'
y_column = 'East' # this was my housing sales value
n_1, n_2 = 5, 5 # size of data before and after the given breakpoint (i.e. 2012)

def find_rss (data, x_column, y_column):
    x = data[[x_column]].iloc[0:10,:]
    y = data[[y_column]].iloc[0:10,:]
    lm = LinearRegression()
    lm.fit(x, y)
    rss = np.sum(np.square(y - lm.predict(x)))
    return rss
rss_total = find_rss(data, x_column, y_column)
#rss_total

rss_1 = find_rss(data.iloc[0:10,:5], x_column, y_column) # data before 2012
rss_2 = find_rss(data.iloc[0:10,5:], x_column, y_column) # data after 2012
rss_1
# chow_nom = (rss_total - (rss_1 + rss_2)) / 2
# chow_denom = (rss_1+rss_2) / (n_1 + n_2 - (2 * 2))
# chow = chow_nom / chow_denom
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-faebb83a562f> in <module>
#      16 #rss_total
#      17
# ---> 18 rss_1 = find_rss(data.iloc[0:10,:5], x_column, y_column) # data before 2012
#      19 rss_2 = find_rss(data.iloc[0:10,5:], x_column, y_column) # data after 2012
#      20 rss_1
#
# <ipython-input-60-faebb83a562f> in find_rss(data, x_column, y_column)
#       7
#       8 def find_rss (data, x_column, y_column):
# ----> 9     x = data[[x_column]].iloc[0:10,:]
#      10     y = data[[y_column]].iloc[0:10,:]
#      11     lm = LinearRegression()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from scipy.stats import f
plt.figure()
X = np.array([[[i, 0, 0] for i in range(2007, 2011)] + [[i, 1, i] for i in range(2011, 2017)]]).reshape(10, 3) #dummy variable
#X
y = [-244000,-262000,-288000,-301000,-347000,-356000,-396000,-446000,-461000,-481000]
reg = LinearRegression().fit(X, y)
reg.score(X, y)
X_n = np.array(list(range(2007, 2017))).reshape(-1, 1)
X_1 = np.array([[i, 0, 0] for i in range(2007, 2011)])
X_2 = np.array([[i, 1, i] for i in range(2011, 2017)])
reg.predict(X_1)
X_n
plt.plot(X_n[:4,0], reg.predict(X_1), "--")
plt.plot(X_n[4:,0], reg.predict(X_2), "--")
plt.plot(X_n, y)

def rss(y, y_pred):
    return mean_squared_error(y, y_pred)
def chow(y, y_pred_all, y_pred_1, y_pred_2, N, k, breakpoint = 4):
    rss_p = rss(y, y_pred_all)
    rss_1 = rss(y[:breakpoint], reg.predict(X_1))
    rss_2 = rss(y[breakpoint:], reg.predict(X_2))
    num = (rss_p - rss_1 - rss_2)/(k)
    den = (rss_1 + rss_2)/(N-2*k)
    return num/den
reg_all = LinearRegression().fit(X_n, y)
y_pred_all = reg_all.predict(X_n)
y_pred_1 = reg.predict(X_1)
y_pred_2 =  reg.predict(X_2)
print(chow(y, y_pred_all, y_pred_1, y_pred_2, 10, 2))
f.ppf(0.95,2,6)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -0.14114584023770144
# 5.143252849784718

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from scipy.stats import f
X = np.array([[[i, 0, 0] for i in range(2003, 2011)] + [[i, 1, i] for i in range(2011, 2020)]]).reshape(17, 3) #dummy variable
X
# y = [(south[i].mean()[size1] - east[i].mean()[size1]) for i in range(2003, 2020)]
# reg = LinearRegression().fit(X, y)
# reg.score(X, y)
# X_n = np.array(list(range(2003, 2020))).reshape(-1, 1)
# X_1 = np.array([[i, 0, 0] for i in range(2003, 2011)])
# X_2 = np.array([[i, 1, i] for i in range(2011, 2020)])
# reg.predict(X_1)
# plt.plot(X_n[:breakpoint,0], reg.predict(X_1), "--")
# plt.plot(X_n[breakpoint:,0], reg.predict(X_2), "--")
# plt.plot(X_n, y)

# def rss(y, y_pred):
#     return mean_squared_error(y, y_pred)
# def chow(y, y_pred_all, y_pred_1, y_pred_2, N, k, breakpoint = 8):
#     rss_p = rss(y, y_pred_all)
#     rss_1 = rss(y[:breakpoint], reg.predict(X_1))
#     rss_2 = rss(y[breakpoint:], reg.predict(X_2))
#     num = (rss_p - rss_1 - rss_2)/(k)
#     den = (rss_1 + rss_2)/(N-2*k)
#     return num/den
# reg_all = LinearRegression().fit(X_n, y)
# y_pred_all = reg_all.predict(X_n)
# y_pred_1 = reg.predict(X_1)
# y_pred_2 =  reg.predict(X_2)
# print(chow(y, y_pred_all, y_pred_1, y_pred_2, 17, 2))
# f.ppf(0.95,2,13)
# Out:
# array([[2003,    0,    0],
#        [2004,    0,    0],
#        [2005,    0,    0],
#        [2006,    0,    0],
#        [2007,    0,    0],
#        [2008,    0,    0],
#        [2009,    0,    0],
#        [2010,    0,    0],
#        [2011,    1, 2011],
#        [2012,    1, 2012],
#        [2013,    1, 2013],
#        [2014,    1, 2014],
#        [2015,    1, 2015],
#        [2016,    1, 2016],
#        [2017,    1, 2017],
#        [2018,    1, 2018],
#        [2019,    1, 2019]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from scipy.stats import f
plt.figure()
X = np.array([[[i, 0, 0] for i in range(2007, 2011)] + [[i, 1, i] for i in range(2011, 2014)]]).reshape(7, 3) #dummy variable
#X
y = [-372,-113,763,515,497,33,1604]
reg = LinearRegression().fit(X, y)
reg.score(X, y)
X_n = np.array(list(range(2007, 2014))).reshape(-1, 1)
X_1 = np.array([[i, 0, 0] for i in range(2007, 2011)])
X_2 = np.array([[i, 1, i] for i in range(2011, 2014)])
reg.predict(X_1)
X_n
plt.plot(X_n[:4,0], reg.predict(X_1), "--")
plt.plot(X_n[4:,0], reg.predict(X_2), "--")
plt.plot(X_n, y)

def rss(y, y_pred):
    return mean_squared_error(y, y_pred)
def chow(y, y_pred_all, y_pred_1, y_pred_2, N, k, breakpoint = 4):
    rss_p = rss(y, y_pred_all)
    rss_1 = rss(y[:breakpoint], reg.predict(X_1))
    rss_2 = rss(y[breakpoint:], reg.predict(X_2))
    num = (rss_p - rss_1 - rss_2)/(k)
    den = (rss_1 + rss_2)/(N-2*k)
    return num/den
reg_all = LinearRegression().fit(X_n, y)
y_pred_all = reg_all.predict(X_n)
y_pred_1 = reg.predict(X_1)
y_pred_2 =  reg.predict(X_2)
print(chow(y, y_pred_all, y_pred_1, y_pred_2, 7, 2))
f.ppf(0.95,2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -0.4969484195421722
# 9.552094495921155
